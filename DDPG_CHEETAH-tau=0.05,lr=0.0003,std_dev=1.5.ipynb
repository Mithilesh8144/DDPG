# %%
import gym
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# %%
import pybullet_envs

# %%
env=gym.make('HalfCheetahBulletEnv-v0')

# %%
env.action_space
# Out:
# Box(6,)

# %%
num_states = env.observation_space.shape[0]
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.shape[0]
print("Size of Action Space ->  {}".format(num_actions))

upper_bound = env.action_space.high[0]
lower_bound = env.action_space.low[0]

print("Max Value of Action ->  {}".format(upper_bound))
print("Min Value of Action ->  {}".format(lower_bound))
# Out:
# Size of State Space ->  26
# Size of Action Space ->  6
# Max Value of Action ->  1.0
# Min Value of Action ->  -1.0

# %%
class OUActionNoise:
    def __init__(self, mean, std_deviation, theta=0.15, dt=1e-2, x_initial=None):
        self.theta = theta
        self.mean = mean
        self.std_dev = std_deviation
        self.dt = dt
        self.x_initial = x_initial
        self.reset()

    def __call__(self):
        # Formula taken from https://www.wikipedia.org/wiki/Ornstein-Uhlenbeck_process.
        x = (
            self.x_prev
            + self.theta * (self.mean - self.x_prev) * self.dt
            + self.std_dev * np.sqrt(self.dt) * np.random.normal(size=self.mean.shape)
        )
        # Store x into x_prev
        # Makes next noise dependent on current one
        self.x_prev = x
        return x

    def reset(self):
        if self.x_initial is not None:
            self.x_prev = self.x_initial
        else:
            self.x_prev = np.zeros_like(self.mean)

# %%
class Buffer:
    def __init__(self, buffer_capacity, batch_size):
        self.buffer_capacity = buffer_capacity
        self.batch_size = batch_size

        self.buffer_counter = 0

        self.state_buffer = np.zeros((self.buffer_capacity, num_states))
        self.action_buffer = np.zeros((self.buffer_capacity, num_actions))
        self.reward_buffer = np.zeros((self.buffer_capacity, 1))
        self.next_state_buffer = np.zeros((self.buffer_capacity, num_states))


    def record(self, obs_tuple):
        index = self.buffer_counter % self.buffer_capacity

        self.state_buffer[index] = obs_tuple[0]
        self.action_buffer[index] = obs_tuple[1]
        self.reward_buffer[index] = obs_tuple[2]
        self.next_state_buffer[index] = obs_tuple[3]

        self.buffer_counter += 1

    def update(self, state_batch, action_batch, reward_batch, next_state_batch,):
        with tf.GradientTape() as tape:
            target_actions = target_actor(next_state_batch, training=True)
            
            
            y = reward_batch + gamma * target_critic([next_state_batch, target_actions], training=True)
            critic_value = critic_model([state_batch, action_batch], training=True)
            critic_loss = tf.math.reduce_mean(tf.math.square(y - critic_value))

        critic_grad = tape.gradient(critic_loss, critic_model.trainable_variables)
        critic_optimizer.apply_gradients(
            zip(critic_grad, critic_model.trainable_variables)
        )

        with tf.GradientTape() as tape:
            actions = actor_model(state_batch, training=True)
            critic_value = critic_model([state_batch, actions], training=True)
            actor_loss = -tf.math.reduce_mean(critic_value)

        actor_grad = tape.gradient(actor_loss, actor_model.trainable_variables)
        actor_optimizer.apply_gradients(
            zip(actor_grad, actor_model.trainable_variables)
        )

    def learn(self):

        record_range = min(self.buffer_counter, self.buffer_capacity)

        batch_indices = np.random.choice(record_range, self.batch_size)

        state_batch = tf.convert_to_tensor(self.state_buffer[batch_indices])
        action_batch = tf.convert_to_tensor(self.action_buffer[batch_indices])
        reward_batch = tf.convert_to_tensor(self.reward_buffer[batch_indices])
        next_state_batch = tf.convert_to_tensor(self.next_state_buffer[batch_indices])
        


        self.update(state_batch, action_batch, reward_batch, next_state_batch)

# %%
@tf.function
def update_target(target_weights, weights, tau):
    for (a, b) in zip(target_weights, weights):
        a.assign(b * tau + a * (1 - tau))

# %%
def get_actor():
    last_init=tf.random_uniform_initializer(minval=-0.003,maxval=0.003)
    i=layers.Input(shape=(num_states))
    x=layers.Dense(128,activation='relu',autocast=False)(i)
    x=layers.Dense(256,activation='relu')(x)
    x=layers.Dense(256,activation='relu')(x)
    x=layers.Dense(num_actions,activation='tanh',kernel_initializer=last_init)(x)
    x=x*upper_bound
    model=tf.keras.Model(i,x)
    return model

# %%
actor=get_actor()

# %%
actor.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 26)]              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 128)               3456
# _________________________________________________________________
# dense_27 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_28 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_29 (Dense)             (None, 6)                 1542
# _________________________________________________________________
# tf_op_layer_mul_3 (TensorFlo [(None, 6)]               0
# =================================================================
# Total params: 103,814
# Trainable params: 103,814
# Non-trainable params: 0
# _________________________________________________________________

# %%
def get_critic():
    state_input=layers.Input(shape=(num_states))
    state_output=layers.Dense(16,activation='relu',autocast=False)(state_input)
    state_output=layers.Dense(32,activation='relu')(state_output)
    
    action_input=layers.Input(shape=(num_actions))
    action_output=layers.Dense(16,activation='relu')(action_input)
    action_output=layers.Dense(32,activation='relu')(action_output)

    concat=layers.Concatenate()([state_output,action_output])
    x=layers.Dense(256,activation='relu')(concat)
    
    x=layers.Dense(256,activation='relu')(x)
    x=layers.Dense(1,activation='linear')(x)
    model=tf.keras.Model([state_input,action_input],x)
    return model

# %%
def policy(state, noise_object):
    sampled_actions = tf.squeeze(actor_model(state))
    noise = noise_object()
    sampled_actions = sampled_actions.numpy() + noise

    legal_action = np.clip(sampled_actions, lower_bound, upper_bound)

    return np.squeeze(legal_action)

# %%
std_dev = 0.15
ou_noise = OUActionNoise(mean=np.zeros(6), std_deviation=float(std_dev) * np.ones(6))

actor_model = get_actor()
critic_model = get_critic()

target_actor = get_actor()
target_critic = get_critic()


target_actor.set_weights(actor_model.get_weights())
target_critic.set_weights(critic_model.get_weights())


critic_lr = 0.0003
actor_lr = 0.0003

critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

total_episodes = 500

gamma = 0.99

tau = 0.05

buffer = Buffer(100000, 128)

# %%
tf.keras.backend.set_floatx('float64')

# %%
ep_reward_list = []

avg_reward_list = []


for ep in range(total_episodes):

    prev_state = env.reset()
    episodic_reward = 0

    while True:
        

        tf_prev_state = tf.expand_dims(tf.convert_to_tensor(prev_state), 0)

        action = policy(tf_prev_state, ou_noise)
    
        state, reward, done, info = env.step(action)

        buffer.record((prev_state, action, reward, state))
        episodic_reward += reward

        buffer.learn()
        update_target(target_actor.variables, actor_model.variables, tau)
        update_target(target_critic.variables, critic_model.variables, tau)

        if done:
            break

        prev_state = state

    ep_reward_list.append(episodic_reward)
    avg_reward = np.mean(ep_reward_list[-50:])
    print("Episode * {} * Avg Reward is ==> {}".format(ep, avg_reward))
    avg_reward_list.append(avg_reward)


plt.plot(avg_reward_list)
plt.xlabel("Episode")
plt.ylabel("Avg. Epsiodic Reward")
plt.show()
# Out:
# Episode * 0 * Avg Reward is ==> -1438.634719633557
# Episode * 1 * Avg Reward is ==> -1372.058835254794
# Episode * 2 * Avg Reward is ==> -1490.6866741354488
# Episode * 3 * Avg Reward is ==> -1410.212425275075
# Episode * 4 * Avg Reward is ==> -1386.1864921393133
# Episode * 5 * Avg Reward is ==> -1344.3673431175935
# Episode * 6 * Avg Reward is ==> -1389.7550126825697
# Episode * 7 * Avg Reward is ==> -1412.589131382244
# Episode * 8 * Avg Reward is ==> -1435.4741614705174
# Episode * 9 * Avg Reward is ==> -1447.9485647512495
# Episode * 10 * Avg Reward is ==> -1453.0632683437468
# Episode * 11 * Avg Reward is ==> -1407.6169077749407
# Episode * 12 * Avg Reward is ==> -1397.8658676599157
# Episode * 13 * Avg Reward is ==> -1277.7715411958668
# Episode * 14 * Avg Reward is ==> -1257.4372007067914
# Episode * 15 * Avg Reward is ==> -1283.6597858807172
# Episode * 16 * Avg Reward is ==> -1303.1441795997036
# Episode * 17 * Avg Reward is ==> -1320.5059071846379
# Episode * 18 * Avg Reward is ==> -1324.0115682108997
# Episode * 19 * Avg Reward is ==> -1300.947200010104
# Episode * 20 * Avg Reward is ==> -1286.1206720268028
# Episode * 21 * Avg Reward is ==> -1282.2482805136924
# Episode * 22 * Avg Reward is ==> -1266.8669533012649
# Episode * 23 * Avg Reward is ==> -1269.9512101141638
# Episode * 24 * Avg Reward is ==> -1268.5546148255853
# Episode * 25 * Avg Reward is ==> -1239.9864767006252
# Episode * 26 * Avg Reward is ==> -1249.3402070617487
# Episode * 27 * Avg Reward is ==> -1230.1733805046013
# Episode * 28 * Avg Reward is ==> -1199.2359258696215
# Episode * 29 * Avg Reward is ==> -1155.0014961925897
# Episode * 30 * Avg Reward is ==> -1137.6545239358916
# Episode * 31 * Avg Reward is ==> -1101.7973651175275
# Episode * 32 * Avg Reward is ==> -1063.8003269233138
# Episode * 33 * Avg Reward is ==> -1053.3316869135401
# Episode * 34 * Avg Reward is ==> -1013.0350312022492
# Episode * 35 * Avg Reward is ==> -1019.0665873782569
# Episode * 36 * Avg Reward is ==> -1001.2574518172036
# Episode * 37 * Avg Reward is ==> -964.2370891688894
# Episode * 38 * Avg Reward is ==> -935.1931438222588
# Episode * 39 * Avg Reward is ==> -905.1946737042705
# Episode * 40 * Avg Reward is ==> -884.9997083608592
# Episode * 41 * Avg Reward is ==> -885.4652160366617
# Episode * 42 * Avg Reward is ==> -867.1934392646459
# Episode * 43 * Avg Reward is ==> -867.7630114596706
# Episode * 44 * Avg Reward is ==> -840.0498075306828
# Episode * 45 * Avg Reward is ==> -840.5917389570043
# Episode * 46 * Avg Reward is ==> -835.4786210740691
# Episode * 47 * Avg Reward is ==> -823.0180313798097
# Episode * 48 * Avg Reward is ==> -814.769882496592
# Episode * 49 * Avg Reward is ==> -806.3481830350469
# Episode * 50 * Avg Reward is ==> -769.1000229337077
# Episode * 51 * Avg Reward is ==> -743.8339943618819
# Episode * 52 * Avg Reward is ==> -709.7132355006338
# Episode * 53 * Avg Reward is ==> -699.4246031268298
# Episode * 54 * Avg Reward is ==> -664.9573476516284
# Episode * 55 * Avg Reward is ==> -641.6772217864801
# Episode * 56 * Avg Reward is ==> -598.4747689939111
# Episode * 57 * Avg Reward is ==> -557.7389801701048
# Episode * 58 * Avg Reward is ==> -539.712531352847
# Episode * 59 * Avg Reward is ==> -502.9822304630824
# Episode * 60 * Avg Reward is ==> -488.3101290162074
# Episode * 61 * Avg Reward is ==> -477.14058365107957
# Episode * 62 * Avg Reward is ==> -442.2141218802906
# Episode * 63 * Avg Reward is ==> -448.20115874970986
# Episode * 64 * Avg Reward is ==> -427.63910697690545
# Episode * 65 * Avg Reward is ==> -385.45855325744674
# Episode * 66 * Avg Reward is ==> -356.7165816446356
# Episode * 67 * Avg Reward is ==> -320.0056224185676
# Episode * 68 * Avg Reward is ==> -308.50103091594843
# Episode * 69 * Avg Reward is ==> -293.554102356059
# Episode * 70 * Avg Reward is ==> -263.37307594886573
# Episode * 71 * Avg Reward is ==> -234.37674888361974
# Episode * 72 * Avg Reward is ==> -211.1969102796873
# Episode * 73 * Avg Reward is ==> -183.36038552834353
# Episode * 74 * Avg Reward is ==> -163.2263015619215
# Episode * 75 * Avg Reward is ==> -145.1223568028664
# Episode * 76 * Avg Reward is ==> -105.24915445173167
# Episode * 77 * Avg Reward is ==> -82.08218563808309
# Episode * 78 * Avg Reward is ==> -77.65225515770702
# Episode * 79 * Avg Reward is ==> -83.54299548333361
# Episode * 80 * Avg Reward is ==> -69.31724777317238
# Episode * 81 * Avg Reward is ==> -71.48483168542498
# Episode * 82 * Avg Reward is ==> -66.06482592415198
# Episode * 83 * Avg Reward is ==> -39.494359631095016
# Episode * 84 * Avg Reward is ==> -36.158006556271786
# Episode * 85 * Avg Reward is ==> -4.222961318814559
# Episode * 86 * Avg Reward is ==> 14.774789896472907
# Episode * 87 * Avg Reward is ==> 16.8203816444589
# Episode * 88 * Avg Reward is ==> 24.615595755803987
# Episode * 89 * Avg Reward is ==> 18.857193175822196
# Episode * 90 * Avg Reward is ==> 31.329573842845456
# Episode * 91 * Avg Reward is ==> 35.688154411514276
# Episode * 92 * Avg Reward is ==> 40.85893976277903
# Episode * 93 * Avg Reward is ==> 65.38047464345925
# Episode * 94 * Avg Reward is ==> 66.98080878053837
# Episode * 95 * Avg Reward is ==> 77.00872076830142
# Episode * 96 * Avg Reward is ==> 95.68553914213089
# Episode * 97 * Avg Reward is ==> 112.47095460611378
# Episode * 98 * Avg Reward is ==> 128.29153043489953
# Episode * 99 * Avg Reward is ==> 146.329362143114
# Episode * 100 * Avg Reward is ==> 142.3057746994161
# Episode * 101 * Avg Reward is ==> 146.39789072103784
# Episode * 102 * Avg Reward is ==> 158.77226196022318
# Episode * 103 * Avg Reward is ==> 180.58244622712172
# Episode * 104 * Avg Reward is ==> 168.769159240665
# Episode * 105 * Avg Reward is ==> 179.40804321187443
# Episode * 106 * Avg Reward is ==> 183.06004253315626
# Episode * 107 * Avg Reward is ==> 185.54202918425912
# Episode * 108 * Avg Reward is ==> 210.09368075132323
# Episode * 109 * Avg Reward is ==> 213.67971693440802
# Episode * 110 * Avg Reward is ==> 237.21674297819075
# Episode * 111 * Avg Reward is ==> 253.5500867546153
# Episode * 112 * Avg Reward is ==> 255.07220432638223
# Episode * 113 * Avg Reward is ==> 265.65995801716775
# Episode * 114 * Avg Reward is ==> 275.9733694137545
# Episode * 115 * Avg Reward is ==> 265.9235986497718
# Episode * 116 * Avg Reward is ==> 279.61656268341466
# Episode * 117 * Avg Reward is ==> 286.48635069411927
# Episode * 118 * Avg Reward is ==> 313.872704140001
# Episode * 119 * Avg Reward is ==> 326.9086864691724
# Episode * 120 * Avg Reward is ==> 328.1256499643416
# Episode * 121 * Avg Reward is ==> 335.0906360218003
# Episode * 122 * Avg Reward is ==> 343.5331688311391
# Episode * 123 * Avg Reward is ==> 354.06277753418004
# Episode * 124 * Avg Reward is ==> 360.15482388868315
# Episode * 125 * Avg Reward is ==> 364.0037146001861
# Episode * 126 * Avg Reward is ==> 357.65526214761064
# Episode * 127 * Avg Reward is ==> 358.59302986129086
# Episode * 128 * Avg Reward is ==> 370.2487995404346
# Episode * 129 * Avg Reward is ==> 384.13384822869614
# Episode * 130 * Avg Reward is ==> 392.7284081060486
# Episode * 131 * Avg Reward is ==> 404.73631882945614
# Episode * 132 * Avg Reward is ==> 403.785032979715
# Episode * 133 * Avg Reward is ==> 401.4367113414019
# Episode * 134 * Avg Reward is ==> 398.7653055672561
# Episode * 135 * Avg Reward is ==> 403.9833131634207
# Episode * 136 * Avg Reward is ==> 403.7205246343388
# Episode * 137 * Avg Reward is ==> 398.9151425114786
# Episode * 138 * Avg Reward is ==> 363.04578702761734
# Episode * 139 * Avg Reward is ==> 373.6654681801839
# Episode * 140 * Avg Reward is ==> 372.83397519996316
# Episode * 141 * Avg Reward is ==> 392.1719207378881
# Episode * 142 * Avg Reward is ==> 399.9088373482354
# Episode * 143 * Avg Reward is ==> 402.6507489046674
# Episode * 144 * Avg Reward is ==> 401.86786672299866
# Episode * 145 * Avg Reward is ==> 420.4893833234749
# Episode * 146 * Avg Reward is ==> 425.4999766343997
# Episode * 147 * Avg Reward is ==> 416.5351397206006
# Episode * 148 * Avg Reward is ==> 412.8646252890878
# Episode * 149 * Avg Reward is ==> 414.48034800597685
# Episode * 150 * Avg Reward is ==> 420.8052092052856
# Episode * 151 * Avg Reward is ==> 428.8931529581565
# Episode * 152 * Avg Reward is ==> 428.0003921688851
# Episode * 153 * Avg Reward is ==> 431.6734591671174
# Episode * 154 * Avg Reward is ==> 446.3478069510933
# Episode * 155 * Avg Reward is ==> 449.37312398525034
# Episode * 156 * Avg Reward is ==> 446.9584102296943
# Episode * 157 * Avg Reward is ==> 446.36923063006043
# Episode * 158 * Avg Reward is ==> 448.84327409677627
# Episode * 159 * Avg Reward is ==> 450.66985064567103
# Episode * 160 * Avg Reward is ==> 453.147462776558
# Episode * 161 * Avg Reward is ==> 459.32776798801495
# Episode * 162 * Avg Reward is ==> 462.7038907198613
# Episode * 163 * Avg Reward is ==> 467.1954209686592
# Episode * 164 * Avg Reward is ==> 469.2794999320616
# Episode * 165 * Avg Reward is ==> 483.9450327771236
# Episode * 166 * Avg Reward is ==> 488.9914512823471
# Episode * 167 * Avg Reward is ==> 487.96728147317486
# Episode * 168 * Avg Reward is ==> 490.9827031748606
# Episode * 169 * Avg Reward is ==> 492.2676861438441
# Episode * 170 * Avg Reward is ==> 494.06433326789846
# Episode * 171 * Avg Reward is ==> 491.7440725188959
# Episode * 172 * Avg Reward is ==> 492.1363120599563
# Episode * 173 * Avg Reward is ==> 495.17938004093173
# Episode * 174 * Avg Reward is ==> 506.53859651726236
# Episode * 175 * Avg Reward is ==> 507.1173349769205
# Episode * 176 * Avg Reward is ==> 509.99579800854366
# Episode * 177 * Avg Reward is ==> 507.58299258003353
# Episode * 178 * Avg Reward is ==> 511.74683672031284
# Episode * 179 * Avg Reward is ==> 509.56072010949583
# Episode * 180 * Avg Reward is ==> 510.9767228139263
# Episode * 181 * Avg Reward is ==> 518.0009990508072
# Episode * 182 * Avg Reward is ==> 523.9652766337343
# Episode * 183 * Avg Reward is ==> 529.7657512250884
# Episode * 184 * Avg Reward is ==> 535.2232773294668
# Episode * 185 * Avg Reward is ==> 539.5646966581944
# Episode * 186 * Avg Reward is ==> 535.2300980126694
# Episode * 187 * Avg Reward is ==> 545.857819411594
# Episode * 188 * Avg Reward is ==> 585.4740806394223
# Episode * 189 * Avg Reward is ==> 591.6182951485252
# Episode * 190 * Avg Reward is ==> 594.5972996513868
# Episode * 191 * Avg Reward is ==> 601.8929618569058
# Episode * 192 * Avg Reward is ==> 599.5233699440072
# Episode * 193 * Avg Reward is ==> 598.182746910717
# Episode * 194 * Avg Reward is ==> 600.9764649146975
# Episode * 195 * Avg Reward is ==> 601.7307712630301
# Episode * 196 * Avg Reward is ==> 603.5889319763209
# Episode * 197 * Avg Reward is ==> 615.8042083238001
# Episode * 198 * Avg Reward is ==> 625.6106157611808
# Episode * 199 * Avg Reward is ==> 631.0282230611601
# Episode * 200 * Avg Reward is ==> 637.224944892764
# Episode * 201 * Avg Reward is ==> 639.7839591762017
# Episode * 202 * Avg Reward is ==> 640.3455242512316
# Episode * 203 * Avg Reward is ==> 644.8674390888776
# Episode * 204 * Avg Reward is ==> 650.2964636469482
# Episode * 205 * Avg Reward is ==> 653.5998877827855
# Episode * 206 * Avg Reward is ==> 660.4517403759181
# Episode * 207 * Avg Reward is ==> 665.3941506248541
# Episode * 208 * Avg Reward is ==> 667.9018911903855
# Episode * 209 * Avg Reward is ==> 675.075033845253
# Episode * 210 * Avg Reward is ==> 681.4332639967222
# Episode * 211 * Avg Reward is ==> 684.0687514833954
# Episode * 212 * Avg Reward is ==> 690.8957447315591
# Episode * 213 * Avg Reward is ==> 698.8620004276978
# Episode * 214 * Avg Reward is ==> 705.1734059467962
# Episode * 215 * Avg Reward is ==> 712.2596718412633
# Episode * 216 * Avg Reward is ==> 716.4059404892495
# Episode * 217 * Avg Reward is ==> 726.3207149100776
# Episode * 218 * Avg Reward is ==> 734.4972119788055
# Episode * 219 * Avg Reward is ==> 742.4209951475146
# Episode * 220 * Avg Reward is ==> 746.6192080322841
# Episode * 221 * Avg Reward is ==> 753.8887254694844
# Episode * 222 * Avg Reward is ==> 759.4899602641686
# Episode * 223 * Avg Reward is ==> 758.0363054279755
# Episode * 224 * Avg Reward is ==> 760.3814403888272
# Episode * 225 * Avg Reward is ==> 768.5706767528178
# Episode * 226 * Avg Reward is ==> 783.9095962990491
# Episode * 227 * Avg Reward is ==> 789.0105717924141
# Episode * 228 * Avg Reward is ==> 786.9714896835736
# Episode * 229 * Avg Reward is ==> 795.933637353584
# Episode * 230 * Avg Reward is ==> 796.3815346571388
# Episode * 231 * Avg Reward is ==> 798.2245852273122
# Episode * 232 * Avg Reward is ==> 805.2090363512949
# Episode * 233 * Avg Reward is ==> 812.0151479665257
# Episode * 234 * Avg Reward is ==> 821.4008905394453
# Episode * 235 * Avg Reward is ==> 823.819324297042
# Episode * 236 * Avg Reward is ==> 833.5999374217375
# Episode * 237 * Avg Reward is ==> 838.8789507716677
# Episode * 238 * Avg Reward is ==> 836.5050463457337
# Episode * 239 * Avg Reward is ==> 840.8729346976414
# Episode * 240 * Avg Reward is ==> 850.5368264553779
# Episode * 241 * Avg Reward is ==> 852.4827021352016
# Episode * 242 * Avg Reward is ==> 854.0662782901144
# Episode * 243 * Avg Reward is ==> 869.1493898078411
# Episode * 244 * Avg Reward is ==> 881.3343845464199
# Episode * 245 * Avg Reward is ==> 889.269035789135
# Episode * 246 * Avg Reward is ==> 899.1767602256541
# Episode * 247 * Avg Reward is ==> 904.8586332650145
# Episode * 248 * Avg Reward is ==> 905.1932779450115
# Episode * 249 * Avg Reward is ==> 906.1727453864618
# Episode * 250 * Avg Reward is ==> 908.1867446211585
# Episode * 251 * Avg Reward is ==> 910.25654576405
# Episode * 252 * Avg Reward is ==> 922.6613065057567
# Episode * 253 * Avg Reward is ==> 927.8569433673291
# Episode * 254 * Avg Reward is ==> 931.7069128191963
# Episode * 255 * Avg Reward is ==> 934.947949487162
# Episode * 256 * Avg Reward is ==> 937.271567216587
# Episode * 257 * Avg Reward is ==> 933.8587147780127
# Episode * 258 * Avg Reward is ==> 939.3124714897098
# Episode * 259 * Avg Reward is ==> 938.0631556021668
# Episode * 260 * Avg Reward is ==> 939.3471527622622
# Episode * 261 * Avg Reward is ==> 944.789352829571
# Episode * 262 * Avg Reward is ==> 945.2290096771699
# Episode * 263 * Avg Reward is ==> 943.109902737569
# Episode * 264 * Avg Reward is ==> 947.7939117656612
# Episode * 265 * Avg Reward is ==> 949.7126867433933
# Episode * 266 * Avg Reward is ==> 955.6012479265578
# Episode * 267 * Avg Reward is ==> 959.6237292501157
# Episode * 268 * Avg Reward is ==> 961.6240724089567
# Episode * 269 * Avg Reward is ==> 968.0635265354126
# Episode * 270 * Avg Reward is ==> 973.2653527374334
# Episode * 271 * Avg Reward is ==> 979.0147029005983
# Episode * 272 * Avg Reward is ==> 980.5808676408918
# Episode * 273 * Avg Reward is ==> 980.9270554853013
# Episode * 274 * Avg Reward is ==> 987.3430524877633
# Episode * 275 * Avg Reward is ==> 986.7116209814126
# Episode * 276 * Avg Reward is ==> 976.4751780991942
# Episode * 277 * Avg Reward is ==> 986.047001799248
# Episode * 278 * Avg Reward is ==> 999.2398620184428
# Episode * 279 * Avg Reward is ==> 1005.3467869816819
# Episode * 280 * Avg Reward is ==> 1011.5925966881757
# Episode * 281 * Avg Reward is ==> 1005.5061554673798
# Episode * 282 * Avg Reward is ==> 1006.5845658098951
# Episode * 283 * Avg Reward is ==> 1008.264257920698
# Episode * 284 * Avg Reward is ==> 1008.3429900874778
# Episode * 285 * Avg Reward is ==> 1014.2277311877295
# Episode * 286 * Avg Reward is ==> 1018.3175596989306
# Episode * 287 * Avg Reward is ==> 1015.6203815067066
# Episode * 288 * Avg Reward is ==> 1025.8633889882062
# Episode * 289 * Avg Reward is ==> 1021.4629252541627
# Episode * 290 * Avg Reward is ==> 1006.5389112673411
# Episode * 291 * Avg Reward is ==> 1014.0407602182611
# Episode * 292 * Avg Reward is ==> 1027.195243460906
# Episode * 293 * Avg Reward is ==> 1030.3218281402108
# Episode * 294 * Avg Reward is ==> 1030.0038899402293
# Episode * 295 * Avg Reward is ==> 1036.938035898153
# Episode * 296 * Avg Reward is ==> 1035.464474544673
# Episode * 297 * Avg Reward is ==> 1041.1743785822014
# Episode * 298 * Avg Reward is ==> 1050.6563343038451
# Episode * 299 * Avg Reward is ==> 1058.9161552515307
# Episode * 300 * Avg Reward is ==> 1067.528469479112
# Episode * 301 * Avg Reward is ==> 1069.675500566431
# Episode * 302 * Avg Reward is ==> 1071.8366164177203
# Episode * 303 * Avg Reward is ==> 1077.3644340029246
# Episode * 304 * Avg Reward is ==> 1080.5848932717372
# Episode * 305 * Avg Reward is ==> 1085.7056634863804
# Episode * 306 * Avg Reward is ==> 1084.680532419812
# Episode * 307 * Avg Reward is ==> 1078.7915648924477
# Episode * 308 * Avg Reward is ==> 1084.2535649364413
# Episode * 309 * Avg Reward is ==> 1093.1868417257965
# Episode * 310 * Avg Reward is ==> 1098.2457000785673
# Episode * 311 * Avg Reward is ==> 1100.2240782741685
# Episode * 312 * Avg Reward is ==> 1104.5008698752472
# Episode * 313 * Avg Reward is ==> 1101.3973230985828
# Episode * 314 * Avg Reward is ==> 1100.642301109939
# Episode * 315 * Avg Reward is ==> 1105.7572901314668
# Episode * 316 * Avg Reward is ==> 1107.177090419043
# Episode * 317 * Avg Reward is ==> 1109.2352089523267
# Episode * 318 * Avg Reward is ==> 1112.9591668600701
# Episode * 319 * Avg Reward is ==> 1115.5990410936183
# Episode * 320 * Avg Reward is ==> 1115.3857942106472
# Episode * 321 * Avg Reward is ==> 1109.9605426127873
# Episode * 322 * Avg Reward is ==> 1109.0572692613187
# Episode * 323 * Avg Reward is ==> 1105.0028118017399
# Episode * 324 * Avg Reward is ==> 1108.3978354632914
# Episode * 325 * Avg Reward is ==> 1116.0853426770075
# Episode * 326 * Avg Reward is ==> 1131.3504501475018
# Episode * 327 * Avg Reward is ==> 1136.4081068286557
# Episode * 328 * Avg Reward is ==> 1138.315883191689
# Episode * 329 * Avg Reward is ==> 1142.6931125650326
# Episode * 330 * Avg Reward is ==> 1152.0017287443347
# Episode * 331 * Avg Reward is ==> 1167.0198710936497
# Episode * 332 * Avg Reward is ==> 1171.8109776777674
# Episode * 333 * Avg Reward is ==> 1173.8970098394245
# Episode * 334 * Avg Reward is ==> 1179.1518465450024
# Episode * 335 * Avg Reward is ==> 1142.8695697497108
# Episode * 336 * Avg Reward is ==> 1094.661427285143
# Episode * 337 * Avg Reward is ==> 1069.39824560973
# Episode * 338 * Avg Reward is ==> 1053.568911207274
# Episode * 339 * Avg Reward is ==> 1044.5187287524727
# Episode * 340 * Avg Reward is ==> 1054.4545215937644
# Episode * 341 * Avg Reward is ==> 1052.2157359613934
# Episode * 342 * Avg Reward is ==> 1054.7299736211614
# Episode * 343 * Avg Reward is ==> 1052.3426610335
# Episode * 344 * Avg Reward is ==> 1057.4739956608692
# Episode * 345 * Avg Reward is ==> 1050.3978837724344
# Episode * 346 * Avg Reward is ==> 1051.0044720610695
# Episode * 347 * Avg Reward is ==> 1049.9934211727418
# Episode * 348 * Avg Reward is ==> 1054.316625949161
# Episode * 349 * Avg Reward is ==> 1056.701790958853
# Episode * 350 * Avg Reward is ==> 1055.0819350174677
# Episode * 351 * Avg Reward is ==> 1059.9088446460262
# Episode * 352 * Avg Reward is ==> 1054.883635669989
# Episode * 353 * Avg Reward is ==> 1051.3997105735057
# Episode * 354 * Avg Reward is ==> 1045.9005055233104
# Episode * 355 * Avg Reward is ==> 1018.7090126857694
# Episode * 356 * Avg Reward is ==> 1025.367051937504
# Episode * 357 * Avg Reward is ==> 1044.6954633394203
# Episode * 358 * Avg Reward is ==> 1030.377062072172
# Episode * 359 * Avg Reward is ==> 1024.249503428785
# Episode * 360 * Avg Reward is ==> 1023.210526856714
# Episode * 361 * Avg Reward is ==> 1019.5281633688551
# Episode * 362 * Avg Reward is ==> 1024.5343140259276
# Episode * 363 * Avg Reward is ==> 1028.2484438765414
# Episode * 364 * Avg Reward is ==> 1032.50634215267
# Episode * 365 * Avg Reward is ==> 1026.2178388808795
# Episode * 366 * Avg Reward is ==> 997.8460393968822
# Episode * 367 * Avg Reward is ==> 1001.6041643934855
# Episode * 368 * Avg Reward is ==> 999.6411523612318
# Episode * 369 * Avg Reward is ==> 999.9600883826699
# Episode * 370 * Avg Reward is ==> 1006.1894088433046
# Episode * 371 * Avg Reward is ==> 1016.440813538013
# Episode * 372 * Avg Reward is ==> 1014.5452708392196
# Episode * 373 * Avg Reward is ==> 1029.4350145848634
# Episode * 374 * Avg Reward is ==> 1031.447565320258
# Episode * 375 * Avg Reward is ==> 1031.4834128674888
# Episode * 376 * Avg Reward is ==> 1034.5264784981737
# Episode * 377 * Avg Reward is ==> 1036.4266405567025
# Episode * 378 * Avg Reward is ==> 1034.9595693888425
# Episode * 379 * Avg Reward is ==> 1034.6642395333577
# Episode * 380 * Avg Reward is ==> 1034.7449812973148
# Episode * 381 * Avg Reward is ==> 1031.4650680540103
# Episode * 382 * Avg Reward is ==> 1034.3628060733286
# Episode * 383 * Avg Reward is ==> 1036.7173812570106
# Episode * 384 * Avg Reward is ==> 1038.2860776064636
# Episode * 385 * Avg Reward is ==> 1075.2453883271578
# Episode * 386 * Avg Reward is ==> 1131.672911063713
# Episode * 387 * Avg Reward is ==> 1165.3824389969575
# Episode * 388 * Avg Reward is ==> 1188.046120256193
# Episode * 389 * Avg Reward is ==> 1210.904706192659
# Episode * 390 * Avg Reward is ==> 1222.7568110599416
# Episode * 391 * Avg Reward is ==> 1229.898224267405
# Episode * 392 * Avg Reward is ==> 1229.0094033035386
# Episode * 393 * Avg Reward is ==> 1229.4429845859127
# Episode * 394 * Avg Reward is ==> 1231.7780372421075
# Episode * 395 * Avg Reward is ==> 1240.872926831858
# Episode * 396 * Avg Reward is ==> 1245.6489294841315
# Episode * 397 * Avg Reward is ==> 1237.6993771115795
# Episode * 398 * Avg Reward is ==> 1229.7364593986424
# Episode * 399 * Avg Reward is ==> 1227.091188275454
# Episode * 400 * Avg Reward is ==> 1223.0172356989904
# Episode * 401 * Avg Reward is ==> 1225.4552672478794
# Episode * 402 * Avg Reward is ==> 1232.1571956068572
# Episode * 403 * Avg Reward is ==> 1230.6685514827504
# Episode * 404 * Avg Reward is ==> 1235.596229910945
# Episode * 405 * Avg Reward is ==> 1265.9599532763893
# Episode * 406 * Avg Reward is ==> 1270.5402416495033
# Episode * 407 * Avg Reward is ==> 1273.3574370888098
# Episode * 408 * Avg Reward is ==> 1286.6809669409572
# Episode * 409 * Avg Reward is ==> 1295.796234582467
# Episode * 410 * Avg Reward is ==> 1304.8795391464419
# Episode * 411 * Avg Reward is ==> 1316.5957725536105
# Episode * 412 * Avg Reward is ==> 1311.619524848531
# Episode * 413 * Avg Reward is ==> 1317.4803876731696
# Episode * 414 * Avg Reward is ==> 1318.4892935952794
# Episode * 415 * Avg Reward is ==> 1310.375462302929
# Episode * 416 * Avg Reward is ==> 1337.0830679132685
# Episode * 417 * Avg Reward is ==> 1334.2508016914246
# Episode * 418 * Avg Reward is ==> 1339.2545468411636
# Episode * 419 * Avg Reward is ==> 1336.4344916291652
# Episode * 420 * Avg Reward is ==> 1331.779820431501
# Episode * 421 * Avg Reward is ==> 1333.8146047162334
# Episode * 422 * Avg Reward is ==> 1348.149569111631
# Episode * 423 * Avg Reward is ==> 1357.9966917284848
# Episode * 424 * Avg Reward is ==> 1363.181818933928
# Episode * 425 * Avg Reward is ==> 1366.7636978761664
# Episode * 426 * Avg Reward is ==> 1361.68017396022
# Episode * 427 * Avg Reward is ==> 1360.1658821113951
# Episode * 428 * Avg Reward is ==> 1357.9764344194555
# Episode * 429 * Avg Reward is ==> 1355.7310249628529
# Episode * 430 * Avg Reward is ==> 1357.671710908803
# Episode * 431 * Avg Reward is ==> 1363.4935691752241
# Episode * 432 * Avg Reward is ==> 1367.1614699836405
# Episode * 433 * Avg Reward is ==> 1371.1481063914678
# Episode * 434 * Avg Reward is ==> 1367.8049336473314
# Episode * 435 * Avg Reward is ==> 1369.4237196100587
# Episode * 436 * Avg Reward is ==> 1359.3390826267207
# Episode * 437 * Avg Reward is ==> 1358.05967065051
# Episode * 438 * Avg Reward is ==> 1353.0643285309704
# Episode * 439 * Avg Reward is ==> 1347.1301197897826
# Episode * 440 * Avg Reward is ==> 1345.7220037995132
# Episode * 441 * Avg Reward is ==> 1352.9127980621959
# Episode * 442 * Avg Reward is ==> 1359.658946009891
# Episode * 443 * Avg Reward is ==> 1362.6504901529133
# Episode * 444 * Avg Reward is ==> 1361.8077903569354
# Episode * 445 * Avg Reward is ==> 1361.6000991445212
# Episode * 446 * Avg Reward is ==> 1365.6451828856145
# Episode * 447 * Avg Reward is ==> 1377.3545092530921
# Episode * 448 * Avg Reward is ==> 1388.441687902518
# Episode * 449 * Avg Reward is ==> 1392.4530849225075
# Episode * 450 * Avg Reward is ==> 1385.162731493606
# Episode * 451 * Avg Reward is ==> 1387.8036209906873
# Episode * 452 * Avg Reward is ==> 1385.3321033766779
# Episode * 453 * Avg Reward is ==> 1393.839083351615
# Episode * 454 * Avg Reward is ==> 1398.0631511738334
# Episode * 455 * Avg Reward is ==> 1398.3479729997146
# Episode * 456 * Avg Reward is ==> 1397.7921654856814
# Episode * 457 * Avg Reward is ==> 1392.0383742169777
# Episode * 458 * Avg Reward is ==> 1366.6834174901073
# Episode * 459 * Avg Reward is ==> 1365.9842668244428
# Episode * 460 * Avg Reward is ==> 1362.3022435100374
# Episode * 461 * Avg Reward is ==> 1357.8236985358633
# Episode * 462 * Avg Reward is ==> 1361.268182514178
# Episode * 463 * Avg Reward is ==> 1366.7687742188928
# Episode * 464 * Avg Reward is ==> 1369.4383517999045
# Episode * 465 * Avg Reward is ==> 1355.0059686793836
# Episode * 466 * Avg Reward is ==> 1362.401152963993
# Episode * 467 * Avg Reward is ==> 1358.99952505219
# Episode * 468 * Avg Reward is ==> 1361.9899538571983
# Episode * 469 * Avg Reward is ==> 1365.40258187717
# Episode * 470 * Avg Reward is ==> 1374.150290556042
# Episode * 471 * Avg Reward is ==> 1369.0081622420403
# Episode * 472 * Avg Reward is ==> 1352.3846122605146
# Episode * 473 * Avg Reward is ==> 1339.4466678653307
# Episode * 474 * Avg Reward is ==> 1337.1778571689072
# Episode * 475 * Avg Reward is ==> 1328.7943336287624
# Episode * 476 * Avg Reward is ==> 1326.1157220296625
# Episode * 477 * Avg Reward is ==> 1321.3968116468375
# Episode * 478 * Avg Reward is ==> 1326.0027596430618
# Episode * 479 * Avg Reward is ==> 1326.7306200358987
# Episode * 480 * Avg Reward is ==> 1323.8840370741038
# Episode * 481 * Avg Reward is ==> 1321.2532667300702
# Episode * 482 * Avg Reward is ==> 1315.4994264629242
# Episode * 483 * Avg Reward is ==> 1312.369582019503
# Episode * 484 * Avg Reward is ==> 1317.6380898285563
# Episode * 485 * Avg Reward is ==> 1308.1054622942588
# Episode * 486 * Avg Reward is ==> 1310.711634515529
# Episode * 487 * Avg Reward is ==> 1284.1695306283398
# Episode * 488 * Avg Reward is ==> 1288.3579379313326
# Episode * 489 * Avg Reward is ==> 1292.0200004242404
# Episode * 490 * Avg Reward is ==> 1294.5675437572054
# Episode * 491 * Avg Reward is ==> 1289.6048854715063
# Episode * 492 * Avg Reward is ==> 1289.1452881344294
# Episode * 493 * Avg Reward is ==> 1286.8178684011739
# Episode * 494 * Avg Reward is ==> 1288.594453388794
# Episode * 495 * Avg Reward is ==> 1291.5395114041607
# Episode * 496 * Avg Reward is ==> 1286.4878753572234
# Episode * 497 * Avg Reward is ==> 1292.9182190578251
# Episode * 498 * Avg Reward is ==> 1294.048902862575
# Episode * 499 * Avg Reward is ==> 1297.2895223829487

# %%
no_episodes=[]
for i in range(0,700):
    no_episodes.append(i)

# %%
plt.figure(figsize=(10,5))
plt.plot(no_episodes,ep_reward_list, color = 'red',  linestyle = '-', 
        label = 'Total Reward0')

plt.plot(no_episodes, avg_reward_list, color = 'midnightblue',  linestyle = '--', 
        label = 'Episodes Reward Average0')


plt.grid(b = True, which = 'major', axis = 'y', linestyle = '--')
plt.xlabel('Episode', fontsize = 12)
plt.ylabel('Reward',  fontsize = 12)
plt.title('Total Reward per Testing Episode',  fontsize = 12)  
plt.legend(loc = 'lower right', fontsize = 12)    
plt.show()

# %%
actor_model.save('Cheetah_actor.h5')

# %%
critic_model.save('Cheetah_critic.h5')

# %%
for ep in range(500,700):

    prev_state = env.reset()
    episodic_reward = 0

    while True:
        

        tf_prev_state = tf.expand_dims(tf.convert_to_tensor(prev_state), 0)

        action = policy(tf_prev_state, ou_noise)
    
        state, reward, done, info = env.step(action)

        buffer.record((prev_state, action, reward, state))
        episodic_reward += reward

        buffer.learn()
        update_target(target_actor.variables, actor_model.variables, tau)
        update_target(target_critic.variables, critic_model.variables, tau)

        if done:
            break

        prev_state = state

    ep_reward_list.append(episodic_reward)
    avg_reward = np.mean(ep_reward_list[-50:])
    print("Episode * {} * Avg Reward is ==> {}".format(ep, avg_reward))
    avg_reward_list.append(avg_reward)
# Out:
# Episode * 500 * Avg Reward is ==> 1318.1714488483956
# Episode * 501 * Avg Reward is ==> 1320.5825065772174
# Episode * 502 * Avg Reward is ==> 1323.1363426276882
# Episode * 503 * Avg Reward is ==> 1324.914377464224
# Episode * 504 * Avg Reward is ==> 1327.3868113680908
# Episode * 505 * Avg Reward is ==> 1330.720752027385
# Episode * 506 * Avg Reward is ==> 1316.9254810235311
# Episode * 507 * Avg Reward is ==> 1326.0672774441032
# Episode * 508 * Avg Reward is ==> 1353.6581605197055
# Episode * 509 * Avg Reward is ==> 1348.9286780839875
# Episode * 510 * Avg Reward is ==> 1351.3389527383574
# Episode * 511 * Avg Reward is ==> 1360.4409699190148
# Episode * 512 * Avg Reward is ==> 1362.369846114073
# Episode * 513 * Avg Reward is ==> 1356.567196824956
# Episode * 514 * Avg Reward is ==> 1355.2263440128497
# Episode * 515 * Avg Reward is ==> 1391.4225692689872
# Episode * 516 * Avg Reward is ==> 1388.409054995289
# Episode * 517 * Avg Reward is ==> 1396.6643286996123
# Episode * 518 * Avg Reward is ==> 1351.9017937131166
# Episode * 519 * Avg Reward is ==> 1349.2770909795381
# Episode * 520 * Avg Reward is ==> 1343.4528771072032
# Episode * 521 * Avg Reward is ==> 1352.0531044725553
# Episode * 522 * Avg Reward is ==> 1361.0407742064378
# Episode * 523 * Avg Reward is ==> 1373.062916777042
# Episode * 524 * Avg Reward is ==> 1367.9243085120045
# Episode * 525 * Avg Reward is ==> 1359.0431030468517
# Episode * 526 * Avg Reward is ==> 1367.3321465168046
# Episode * 527 * Avg Reward is ==> 1376.1389388144617
# Episode * 528 * Avg Reward is ==> 1382.460822318081
# Episode * 529 * Avg Reward is ==> 1387.1607603153575
# Episode * 530 * Avg Reward is ==> 1386.4111104243575
# Episode * 531 * Avg Reward is ==> 1383.6079842644112
# Episode * 532 * Avg Reward is ==> 1387.939500412347
# Episode * 533 * Avg Reward is ==> 1386.88790931293
# Episode * 534 * Avg Reward is ==> 1378.3805711194302
# Episode * 535 * Avg Reward is ==> 1389.350210795214
# Episode * 536 * Avg Reward is ==> 1381.988877894134
# Episode * 537 * Avg Reward is ==> 1410.499735080634
# Episode * 538 * Avg Reward is ==> 1387.6529329302375
# Episode * 539 * Avg Reward is ==> 1390.604296621647
# Episode * 540 * Avg Reward is ==> 1392.0261591465717
# Episode * 541 * Avg Reward is ==> 1387.713420180766
# Episode * 542 * Avg Reward is ==> 1389.1288610429913
# Episode * 543 * Avg Reward is ==> 1401.0306283657142
# Episode * 544 * Avg Reward is ==> 1394.591501357639
# Episode * 545 * Avg Reward is ==> 1400.8694984542985
# Episode * 546 * Avg Reward is ==> 1402.3010005775222
# Episode * 547 * Avg Reward is ==> 1394.7140595229048
# Episode * 548 * Avg Reward is ==> 1377.8513611238857
# Episode * 549 * Avg Reward is ==> 1374.8607247896296
# Episode * 550 * Avg Reward is ==> 1369.3553638613128
# Episode * 551 * Avg Reward is ==> 1367.6891512808174
# Episode * 552 * Avg Reward is ==> 1369.8445764339608
# Episode * 553 * Avg Reward is ==> 1349.863344757431
# Episode * 554 * Avg Reward is ==> 1355.1441293870946
# Episode * 555 * Avg Reward is ==> 1358.8163323435876
# Episode * 556 * Avg Reward is ==> 1374.5170388232684
# Episode * 557 * Avg Reward is ==> 1372.4100922689072
# Episode * 558 * Avg Reward is ==> 1377.5987779405466
# Episode * 559 * Avg Reward is ==> 1387.4848765630347
# Episode * 560 * Avg Reward is ==> 1347.3916217735562
# Episode * 561 * Avg Reward is ==> 1342.4149876518463
# Episode * 562 * Avg Reward is ==> 1336.2822076245423
# Episode * 563 * Avg Reward is ==> 1336.6064615387866
# Episode * 564 * Avg Reward is ==> 1333.149776701324
# Episode * 565 * Avg Reward is ==> 1328.9442096153373
# Episode * 566 * Avg Reward is ==> 1330.3762670510616
# Episode * 567 * Avg Reward is ==> 1333.4418448913755
# Episode * 568 * Avg Reward is ==> 1370.4375382351157
# Episode * 569 * Avg Reward is ==> 1377.8353262789387
# Episode * 570 * Avg Reward is ==> 1380.1516246464757
# Episode * 571 * Avg Reward is ==> 1374.2221639693523
# Episode * 572 * Avg Reward is ==> 1383.15824543587
# Episode * 573 * Avg Reward is ==> 1384.0106275418286
# Episode * 574 * Avg Reward is ==> 1391.3249344229434
# Episode * 575 * Avg Reward is ==> 1382.2955808263443
# Episode * 576 * Avg Reward is ==> 1383.6245120981755
# Episode * 577 * Avg Reward is ==> 1378.0501782314207
# Episode * 578 * Avg Reward is ==> 1378.7483081777755
# Episode * 579 * Avg Reward is ==> 1378.9089192254335
# Episode * 580 * Avg Reward is ==> 1387.6060744117651
# Episode * 581 * Avg Reward is ==> 1393.8212746324252
# Episode * 582 * Avg Reward is ==> 1391.1217795198475
# Episode * 583 * Avg Reward is ==> 1392.1511897983366
# Episode * 584 * Avg Reward is ==> 1396.0824816309969
# Episode * 585 * Avg Reward is ==> 1398.377819058956
# Episode * 586 * Avg Reward is ==> 1415.047187911726
# Episode * 587 * Avg Reward is ==> 1413.0913464182086
# Episode * 588 * Avg Reward is ==> 1437.6402342825218
# Episode * 589 * Avg Reward is ==> 1433.6806560783398
# Episode * 590 * Avg Reward is ==> 1409.7214729949528
# Episode * 591 * Avg Reward is ==> 1415.748246525004
# Episode * 592 * Avg Reward is ==> 1411.9435912357446
# Episode * 593 * Avg Reward is ==> 1408.8540240398536
# Episode * 594 * Avg Reward is ==> 1416.8614816168893
# Episode * 595 * Avg Reward is ==> 1405.3805520900978
# Episode * 596 * Avg Reward is ==> 1411.4542341674626
# Episode * 597 * Avg Reward is ==> 1410.4384101678495
# Episode * 598 * Avg Reward is ==> 1399.3057530184317
# Episode * 599 * Avg Reward is ==> 1394.1376074474483
# Episode * 600 * Avg Reward is ==> 1397.5632046770954
# Episode * 601 * Avg Reward is ==> 1403.1244567046067
# Episode * 602 * Avg Reward is ==> 1402.443263579201
# Episode * 603 * Avg Reward is ==> 1418.646293561688
# Episode * 604 * Avg Reward is ==> 1411.1654636606568
# Episode * 605 * Avg Reward is ==> 1404.6624884360426
# Episode * 606 * Avg Reward is ==> 1407.2897871005293
# Episode * 607 * Avg Reward is ==> 1406.2424397522884
# Episode * 608 * Avg Reward is ==> 1398.7437539240473
# Episode * 609 * Avg Reward is ==> 1397.2313495780284
# Episode * 610 * Avg Reward is ==> 1434.3117619227182
# Episode * 611 * Avg Reward is ==> 1424.3861089988861
# Episode * 612 * Avg Reward is ==> 1427.6145082758421
# Episode * 613 * Avg Reward is ==> 1433.216535460788
# Episode * 614 * Avg Reward is ==> 1440.439103180822
# Episode * 615 * Avg Reward is ==> 1438.4207010604298
# Episode * 616 * Avg Reward is ==> 1435.0575647484561
# Episode * 617 * Avg Reward is ==> 1430.2105954935073
# Episode * 618 * Avg Reward is ==> 1431.7626513166754
# Episode * 619 * Avg Reward is ==> 1426.5814548781555
# Episode * 620 * Avg Reward is ==> 1430.1800771255394
# Episode * 621 * Avg Reward is ==> 1433.1637773478142
# Episode * 622 * Avg Reward is ==> 1435.8791074754904
# Episode * 623 * Avg Reward is ==> 1440.1263401307958
# Episode * 624 * Avg Reward is ==> 1439.7953659720667
# Episode * 625 * Avg Reward is ==> 1468.696321999
# Episode * 626 * Avg Reward is ==> 1468.6115667549423
# Episode * 627 * Avg Reward is ==> 1469.9972930731847
# Episode * 628 * Avg Reward is ==> 1462.4753591847643
# Episode * 629 * Avg Reward is ==> 1467.8911533976413
# Episode * 630 * Avg Reward is ==> 1471.4972440181984
# Episode * 631 * Avg Reward is ==> 1472.5180176838833
# Episode * 632 * Avg Reward is ==> 1477.105573797035
# Episode * 633 * Avg Reward is ==> 1457.1496515744898
# Episode * 634 * Avg Reward is ==> 1460.160411097496
# Episode * 635 * Avg Reward is ==> 1463.6261745885483
# Episode * 636 * Avg Reward is ==> 1465.615866919582
# Episode * 637 * Avg Reward is ==> 1473.2485314371959
# Episode * 638 * Avg Reward is ==> 1474.9877209989347
# Episode * 639 * Avg Reward is ==> 1478.5253646410815
# Episode * 640 * Avg Reward is ==> 1494.4115280143264
# Episode * 641 * Avg Reward is ==> 1500.0250758145576
# Episode * 642 * Avg Reward is ==> 1505.1479496999882
# Episode * 643 * Avg Reward is ==> 1505.169783829205
# Episode * 644 * Avg Reward is ==> 1510.8544375154756
# Episode * 645 * Avg Reward is ==> 1520.6642719922777
# Episode * 646 * Avg Reward is ==> 1517.0447548678253
# Episode * 647 * Avg Reward is ==> 1471.5243198461778
# Episode * 648 * Avg Reward is ==> 1460.578463185019
# Episode * 649 * Avg Reward is ==> 1442.6988688675222
# Episode * 650 * Avg Reward is ==> 1415.0407802940224
# Episode * 651 * Avg Reward is ==> 1386.5451347173146
# Episode * 652 * Avg Reward is ==> 1364.5932209508078
# Episode * 653 * Avg Reward is ==> 1351.122201009646
# Episode * 654 * Avg Reward is ==> 1343.419409479373
# Episode * 655 * Avg Reward is ==> 1338.074060361691
# Episode * 656 * Avg Reward is ==> 1323.1995101312546
# Episode * 657 * Avg Reward is ==> 1309.811024075309
# Episode * 658 * Avg Reward is ==> 1306.5239997268316
# Episode * 659 * Avg Reward is ==> 1297.6711940963326
# Episode * 660 * Avg Reward is ==> 1291.4462257092396
# Episode * 661 * Avg Reward is ==> 1291.4978460466386
# Episode * 662 * Avg Reward is ==> 1287.110974474729
# Episode * 663 * Avg Reward is ==> 1279.6322016278243
# Episode * 664 * Avg Reward is ==> 1274.9020672382696
# Episode * 665 * Avg Reward is ==> 1277.6434373659367
# Episode * 666 * Avg Reward is ==> 1277.433252091231
# Episode * 667 * Avg Reward is ==> 1273.6686969595617
# Episode * 668 * Avg Reward is ==> 1277.695182570823
# Episode * 669 * Avg Reward is ==> 1275.393190257384
# Episode * 670 * Avg Reward is ==> 1270.7194434832425
# Episode * 671 * Avg Reward is ==> 1272.4036578725866
# Episode * 672 * Avg Reward is ==> 1264.7035989534568
# Episode * 673 * Avg Reward is ==> 1257.73904995115
# Episode * 674 * Avg Reward is ==> 1249.0467051835797
# Episode * 675 * Avg Reward is ==> 1230.9615206904166
# Episode * 676 * Avg Reward is ==> 1226.8979728672557
# Episode * 677 * Avg Reward is ==> 1228.910243603382
# Episode * 678 * Avg Reward is ==> 1230.9157266625493
# Episode * 679 * Avg Reward is ==> 1222.7270582090523
# Episode * 680 * Avg Reward is ==> 1191.495653661096
# Episode * 681 * Avg Reward is ==> 1188.8446486176588
# Episode * 682 * Avg Reward is ==> 1188.22954264711
# Episode * 683 * Avg Reward is ==> 1205.1842100782364
# Episode * 684 * Avg Reward is ==> 1197.3444883397258
# Episode * 685 * Avg Reward is ==> 1184.1039984565753
# Episode * 686 * Avg Reward is ==> 1174.499135056854
# Episode * 687 * Avg Reward is ==> 1167.243435536213
# Episode * 688 * Avg Reward is ==> 1165.819019228291
# Episode * 689 * Avg Reward is ==> 1163.9771074741573
# Episode * 690 * Avg Reward is ==> 1169.6215019074707
# Episode * 691 * Avg Reward is ==> 1149.392798130923
# Episode * 692 * Avg Reward is ==> 1135.6365322711556
# Episode * 693 * Avg Reward is ==> 1125.1775712655008
# Episode * 694 * Avg Reward is ==> 1118.2116743466736
# Episode * 695 * Avg Reward is ==> 1110.8840917921166
# Episode * 696 * Avg Reward is ==> 1115.1630198847408
# Episode * 697 * Avg Reward is ==> 1153.728747009355
# Episode * 698 * Avg Reward is ==> 1190.2754598657102
# Episode * 699 * Avg Reward is ==> 1207.9454746853503

# %%
plt.figure(figsize=(10,5))
plt.plot(no_episodes,ep_reward_list, color = 'red',  linestyle = '-', 
        label = 'Total Reward0')

plt.plot(no_episodes, avg_reward_list, color = 'midnightblue',  linestyle = '--', 
        label = 'Episodes Reward Average0')


plt.grid(b = True, which = 'major', axis = 'y', linestyle = '--')
plt.xlabel('Episode', fontsize = 12)
plt.ylabel('Reward',  fontsize = 12)
plt.title('Total Reward per Testing Episode',  fontsize = 12)  
plt.legend(loc = 'lower right', fontsize = 12)    
plt.show()
